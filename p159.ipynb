# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

movie = pd.read_csv('../data/movie.csv')

# %%
movie2 = movie[['movie_title', 'imdb_score', 'budget']]
movie_smallest_largest = movie2.nlargest(100, 'imdb_score') \
.nsmallest(5, 'budget')

# %%
movie_smallest_largest
# Out:
#                movie_title  imdb_score    budget
# 4804        Butterfly Girl         8.7  180000.0
# 4801    Children of Heaven         8.5  180000.0
# 4706          12 Angry Men         8.9  350000.0
# 4550          A Separation         8.4  500000.0
# 4636  The Other Dream Team         8.4  500000.0

# %%
movie2.sort_values('imdb_score', ascending=False).head(100)
# Out:
#                                             movie_title  imdb_score  \
# 2725                                   Towering Inferno         9.5
# 1920                           The Shawshank Redemption         9.3
# 3402                                      The Godfather         9.2
# 2779                                            Dekalog         9.1
# 4312                               Kickboxer: Vengeance         9.1
# 3415                                              Fargo         9.0
# 2791                             The Godfather: Part II         9.0
# 66                                      The Dark Knight         9.0
# 1857                                   Schindler's List         8.9
# 335       The Lord of the Rings: The Return of the King         8.9
# 3295                                       Pulp Fiction         8.9
# 4706                                       12 Angry Men         8.9
# 4397                     The Good, the Bad and the Ugly         8.9
# 267   The Lord of the Rings: The Fellowship of the Ring         8.8
# 1825                  It's Always Sunny in Philadelphia         8.8
# 453                                           Daredevil         8.8
# 827                                        Forrest Gump         8.8
# 675                                          Fight Club         8.8
# 97                                            Inception         8.8
# 2031     Star Wars: Episode V - The Empire Strikes Back         8.8
# 2973                 Star Wars: Episode IV - A New Hope         8.7
# 4804                                     Butterfly Girl         8.7
# 1801                                   The Honeymooners         8.7
# 4277                        A Beginner's Guide to Snuff         8.7
# 647                                          The Matrix         8.7
# 1604                                Friday Night Lights         8.7
# 4369                             Queen of the Mountains         8.7
# 1886                                         Goodfellas         8.7
# 3512                                           Gomorrah         8.7
# 3795                    One Flew Over the Cuckoo's Nest         8.7
# ...                                                 ...         ...
# 2334                                 Back to the Future         8.5
# 2215                                             Psycho         8.5
# 1287                                             Amélie         8.4
# 1521         Star Wars: Episode VI - Return of the Jedi         8.4
# 4023                                             Oldboy         8.4
# 58                                               WALL·E         8.4
# 3592                                   The Inbetweeners         8.4
# 3555                                      Veronica Mars         8.4
# 1317                           Baahubali: The Beginning         8.4
# 848                                       Stargate SG-1         8.4
# 1490                                 Lion of the Desert         8.4
# 4395                                     Reservoir Dogs         8.4
# 2294                                  Princess Mononoke         8.4
# 2570                                    American Beauty         8.4
# 567                                          Braveheart         8.4
# 1698                        Once Upon a Time in America         8.4
# 2646                                              U2 3D         8.4
# 2922                                           Das Boot         8.4
# 4163                              To Kill a Mockingbird         8.4
# 2605                                 Lawrence of Arabia         8.4
# 3616                                    Rang De Basanti         8.4
# 4815                          A Charlie Brown Christmas         8.4
# 2333                                        The Shining         8.4
# 3736                                              Psych         8.4
# 3902                                            M*A*S*H         8.4
# 3799                               Anne of Green Gables         8.4
# 3777                                Requiem for a Dream         8.4
# 3935            Batman: The Dark Knight Returns, Part 2         8.4
# 4636                               The Other Dream Team         8.4
# 2455                                             Aliens         8.4
#
#             budget
# 2725           NaN
# 1920  2.500000e+07
# 3402  6.000000e+06
# 2779           NaN
# 4312  1.700000e+07
# 3415           NaN
# 2791  1.300000e+07
# 66    1.850000e+08
# 1857  2.200000e+07
# 335   9.400000e+07
# 3295  8.000000e+06
# 4706  3.500000e+05
# 4397  1.200000e+06
# 267   9.300000e+07
# 1825           NaN
# 453            NaN
# 827   5.500000e+07
# 675   6.300000e+07
# 97    1.600000e+08
# 2031  1.800000e+07
# 2973  1.100000e+07
# 4804  1.800000e+05
# 1801           NaN
# 4277           NaN
# 647   6.300000e+07
# 1604           NaN
# 4369  1.400000e+06
# 1886  2.500000e+07
# 3512           NaN
# 3795  4.400000e+06
# ...            ...
# 2334  1.900000e+07
# 2215  8.069470e+05
# 1287  7.700000e+07
# 1521  3.250000e+07
# 4023  3.000000e+06
# 58    1.800000e+08
# 3592           NaN
# 3555           NaN
# 1317  1.802615e+07
# 848   1.400000e+06
# 1490  3.500000e+07
# 4395  1.200000e+06
# 2294  2.400000e+09
# 2570  1.500000e+07
# 567   7.200000e+07
# 1698  3.000000e+07
# 2646           NaN
# 2922  1.400000e+07
# 4163  2.000000e+06
# 2605  1.500000e+07
# 3616           NaN
# 4815  1.500000e+05
# 2333  1.900000e+07
# 3736           NaN
# 3902           NaN
# 3799           NaN
# 3777  4.500000e+06
# 3935  3.500000e+06
# 4636  5.000000e+05
# 2455  1.850000e+07
#
# [100 rows x 3 columns]

# %%
movie2.sort_values('imdb_score', ascending=False).head(100) \
.sort_values('budget').head()
# Out:
#                     movie_title  imdb_score    budget
# 4815  A Charlie Brown Christmas         8.4  150000.0
# 4801         Children of Heaven         8.5  180000.0
# 4804             Butterfly Girl         8.7  180000.0
# 4706               12 Angry Men         8.9  350000.0
# 4636       The Other Dream Team         8.4  500000.0

# %%
movie2.nlargest(100, 'imdb_score').tail()
# Out:
#                 movie_title  imdb_score     budget
# 4023                 Oldboy         8.4  3000000.0
# 4163  To Kill a Mockingbird         8.4  2000000.0
# 4395         Reservoir Dogs         8.4  1200000.0
# 4550           A Separation         8.4   500000.0
# 4636   The Other Dream Team         8.4   500000.0

# %%
movie2.sort_values('imdb_score', ascending=False).head(100).tail()
# Out:
#                                   movie_title  imdb_score      budget
# 3799                     Anne of Green Gables         8.4         NaN
# 3777                      Requiem for a Dream         8.4   4500000.0
# 3935  Batman: The Dark Knight Returns, Part 2         8.4   3500000.0
# 4636                     The Other Dream Team         8.4    500000.0
# 2455                                   Aliens         8.4  18500000.0
